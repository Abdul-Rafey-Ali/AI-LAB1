# %% [markdown]
# # Minimax Algorithm (Lab 8)
#
# This notebook demonstrates the Minimax recursion for a complete binary tree encoded by leaf scores.
#
# The implementation is in `src/minimax.py`.

# %%
from src.minimax import compute_optimal_value

scores = [3, 5, 2, 9, 3, 5, 2, 9]
result = compute_optimal_value(scores)
result

# %%
print('The optimal value is :', result.value)
